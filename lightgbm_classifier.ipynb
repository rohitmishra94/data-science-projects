# %%
#dataset link for this project
#---https://drive.google.com/drive/folders/1cGIrzjs_aIfucCFGwGPLA4tXUAlR8b8H?usp=sharing

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split


from sklearn.metrics import recall_score
from imblearn.over_sampling import ADASYN
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading csv file, filling nan values and dropping unnecessary columns

# %%
# reading training data
data=pd.read_csv('Train.csv')

data.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   174   1.0    92    29    36                 0
# 1   236   1.0   103   142    34                 1
# 2   174   1.0   110    93    34                 1
# 3   249   1.0    72    29    34                 1
# 4   174   0.0   112    29    43                 1

# %%
# checking null values
data.isnull().sum()
# Out:
# INCIDENT_ID           0
# DATE                  0
# X_1                   0
# X_2                   0
# X_3                   0
# X_4                   0
# X_5                   0
# X_6                   0
# X_7                   0
# X_8                   0
# X_9                   0
# X_10                  0
# X_11                  0
# X_12                182
# X_13                  0
# X_14                  0
# X_15                  0
# MULTIPLE_OFFENSE      0
# dtype: int64

# %%
#dropping columns and filling nan values with median values.
# Assumption:
#1. incident_id and date columns are not needed to predict 
#2. filling nan values with median to avoid effect of outliers if any present

data=data.drop(columns=['INCIDENT_ID','DATE'])

data['X_12']=data['X_12'].fillna(data['X_12'].median())

# %%
# poping target column
y=data.pop('MULTIPLE_OFFENSE')

# %%
ada = ADASYN(random_state=42)
data, y = ada.fit_resample(data, y)
print('Resampled dataset shape %s' % Counter(y))
# Out:
# Resampled dataset shape Counter({0: 22897, 1: 22788})

# %%
# splitting the training data in test and validation
xtrain,xtest,ytrain,ytest=train_test_split(data,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Fitting classifier and predicting score over validation set

# %%
import lightgbm 

train_data = lightgbm.Dataset(xtrain, label=ytrain)
test_data = lightgbm.Dataset(xtest, label=ytest)

parameters = {
    'application': 'binary',
    'objective': 'binary',
    'metric': 'auc',
    'is_unbalance': 'true',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'feature_fraction': 0.5,
    'bagging_fraction': 0.5,
    'bagging_freq': 20,
    'learning_rate': 0.05,
    'verbose': 0
}

model = lightgbm.train(parameters,
                       train_data,
                       valid_sets=test_data,
                       num_boost_round=5000,
                       early_stopping_rounds=100)
# Out:
# [1]	valid_0's auc: 0.982837
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.999367
# [3]	valid_0's auc: 0.998959
# [4]	valid_0's auc: 0.999518
# [5]	valid_0's auc: 0.999675
# [6]	valid_0's auc: 0.999698
# [7]	valid_0's auc: 0.999765
# [8]	valid_0's auc: 0.999872
# [9]	valid_0's auc: 0.999844
# [10]	valid_0's auc: 0.999831
# [11]	valid_0's auc: 0.999852
# [12]	valid_0's auc: 0.999834
# [13]	valid_0's auc: 0.999811
# [14]	valid_0's auc: 0.999832
# [15]	valid_0's auc: 0.999814
# [16]	valid_0's auc: 0.999831
# [17]	valid_0's auc: 0.999825
# [18]	valid_0's auc: 0.99985
# [19]	valid_0's auc: 0.999862
# [20]	valid_0's auc: 0.999878
# [21]	valid_0's auc: 0.999873
# [22]	valid_0's auc: 0.999873
# [23]	valid_0's auc: 0.999875
# [24]	valid_0's auc: 0.999874
# [25]	valid_0's auc: 0.999874
# [26]	valid_0's auc: 0.999875
# [27]	valid_0's auc: 0.999878
# [28]	valid_0's auc: 0.999878
# [29]	valid_0's auc: 0.999885
# [30]	valid_0's auc: 0.999878
# [31]	valid_0's auc: 0.999891
# [32]	valid_0's auc: 0.999895
# [33]	valid_0's auc: 0.999888
# [34]	valid_0's auc: 0.999892
# [35]	valid_0's auc: 0.999905
# [36]	valid_0's auc: 0.999899
# [37]	valid_0's auc: 0.999901
# [38]	valid_0's auc: 0.999897
# [39]	valid_0's auc: 0.999894
# [40]	valid_0's auc: 0.999898
# [41]	valid_0's auc: 0.999922
# [42]	valid_0's auc: 0.99993
# [43]	valid_0's auc: 0.999929
# [44]	valid_0's auc: 0.99993
# [45]	valid_0's auc: 0.999929
# [46]	valid_0's auc: 0.999927
# [47]	valid_0's auc: 0.999928
# [48]	valid_0's auc: 0.999925
# [49]	valid_0's auc: 0.999923
# [50]	valid_0's auc: 0.999921
# [51]	valid_0's auc: 0.999927
# [52]	valid_0's auc: 0.999928
# [53]	valid_0's auc: 0.999928
# [54]	valid_0's auc: 0.999933
# [55]	valid_0's auc: 0.999935
# [56]	valid_0's auc: 0.999939
# [57]	valid_0's auc: 0.999941
# [58]	valid_0's auc: 0.999947
# [59]	valid_0's auc: 0.999951
# [60]	valid_0's auc: 0.999952
# [61]	valid_0's auc: 0.999955
# [62]	valid_0's auc: 0.999961
# [63]	valid_0's auc: 0.999962
# [64]	valid_0's auc: 0.999964
# [65]	valid_0's auc: 0.999965
# [66]	valid_0's auc: 0.999965
# [67]	valid_0's auc: 0.999966
# [68]	valid_0's auc: 0.999966
# [69]	valid_0's auc: 0.999967
# [70]	valid_0's auc: 0.999968
# [71]	valid_0's auc: 0.999967
# [72]	valid_0's auc: 0.999968
# [73]	valid_0's auc: 0.999968
# [74]	valid_0's auc: 0.999967
# [75]	valid_0's auc: 0.999969
# [76]	valid_0's auc: 0.999969
# [77]	valid_0's auc: 0.999968
# [78]	valid_0's auc: 0.99997
# [79]	valid_0's auc: 0.999971
# [80]	valid_0's auc: 0.999973
# [81]	valid_0's auc: 0.999974
# [82]	valid_0's auc: 0.999974
# [83]	valid_0's auc: 0.999975
# [84]	valid_0's auc: 0.999977
# [85]	valid_0's auc: 0.999977
# [86]	valid_0's auc: 0.99998
# [87]	valid_0's auc: 0.99998
# [88]	valid_0's auc: 0.99998
# [89]	valid_0's auc: 0.999982
# [90]	valid_0's auc: 0.999982
# [91]	valid_0's auc: 0.999982
# [92]	valid_0's auc: 0.999983
# [93]	valid_0's auc: 0.999983
# [94]	valid_0's auc: 0.999984
# [95]	valid_0's auc: 0.999984
# [96]	valid_0's auc: 0.999985
# [97]	valid_0's auc: 0.999985
# [98]	valid_0's auc: 0.999985
# [99]	valid_0's auc: 0.999986
# [100]	valid_0's auc: 0.999986
# [101]	valid_0's auc: 0.999987
# [102]	valid_0's auc: 0.999988
# [103]	valid_0's auc: 0.999988
# [104]	valid_0's auc: 0.999988
# [105]	valid_0's auc: 0.999989
# [106]	valid_0's auc: 0.999988
# [107]	valid_0's auc: 0.999988
# [108]	valid_0's auc: 0.999988
# [109]	valid_0's auc: 0.999988
# [110]	valid_0's auc: 0.999989
# [111]	valid_0's auc: 0.999989
# [112]	valid_0's auc: 0.999989
# [113]	valid_0's auc: 0.999989
# [114]	valid_0's auc: 0.99999
# [115]	valid_0's auc: 0.99999
# [116]	valid_0's auc: 0.99999
# [117]	valid_0's auc: 0.99999
# [118]	valid_0's auc: 0.99999
# [119]	valid_0's auc: 0.99999
# [120]	valid_0's auc: 0.99999
# [121]	valid_0's auc: 0.99999
# [122]	valid_0's auc: 0.99999
# [123]	valid_0's auc: 0.99999
# [124]	valid_0's auc: 0.999991
# [125]	valid_0's auc: 0.999991
# [126]	valid_0's auc: 0.999991
# [127]	valid_0's auc: 0.999991
# [128]	valid_0's auc: 0.999991
# [129]	valid_0's auc: 0.999991
# [130]	valid_0's auc: 0.999991
# [131]	valid_0's auc: 0.999991
# [132]	valid_0's auc: 0.999992
# [133]	valid_0's auc: 0.999992
# [134]	valid_0's auc: 0.999992
# [135]	valid_0's auc: 0.999992
# [136]	valid_0's auc: 0.999992
# [137]	valid_0's auc: 0.999992
# [138]	valid_0's auc: 0.999992
# [139]	valid_0's auc: 0.999993
# [140]	valid_0's auc: 0.999993
# [141]	valid_0's auc: 0.999993
# [142]	valid_0's auc: 0.999993
# [143]	valid_0's auc: 0.999993
# [144]	valid_0's auc: 0.999993
# [145]	valid_0's auc: 0.999993
# [146]	valid_0's auc: 0.999993
# [147]	valid_0's auc: 0.999993
# [148]	valid_0's auc: 0.999994
# [149]	valid_0's auc: 0.999994
# [150]	valid_0's auc: 0.999994
# [151]	valid_0's auc: 0.999994
# [152]	valid_0's auc: 0.999994
# [153]	valid_0's auc: 0.999994
# [154]	valid_0's auc: 0.999994
# [155]	valid_0's auc: 0.999994
# [156]	valid_0's auc: 0.999994
# [157]	valid_0's auc: 0.999994
# [158]	valid_0's auc: 0.999994
# [159]	valid_0's auc: 0.999994
# [160]	valid_0's auc: 0.999995
# [161]	valid_0's auc: 0.999994
# [162]	valid_0's auc: 0.999994
# [163]	valid_0's auc: 0.999994
# [164]	valid_0's auc: 0.999994
# [165]	valid_0's auc: 0.999994
# [166]	valid_0's auc: 0.999995
# [167]	valid_0's auc: 0.999995
# [168]	valid_0's auc: 0.999994
# [169]	valid_0's auc: 0.999994
# [170]	valid_0's auc: 0.999995
# [171]	valid_0's auc: 0.999994
# [172]	valid_0's auc: 0.999994
# [173]	valid_0's auc: 0.999994
# [174]	valid_0's auc: 0.999994
# [175]	valid_0's auc: 0.999994
# [176]	valid_0's auc: 0.999994
# [177]	valid_0's auc: 0.999994
# [178]	valid_0's auc: 0.999995
# [179]	valid_0's auc: 0.999994
# [180]	valid_0's auc: 0.999994
# [181]	valid_0's auc: 0.999994
# [182]	valid_0's auc: 0.999994
# [183]	valid_0's auc: 0.999995
# [184]	valid_0's auc: 0.999995
# [185]	valid_0's auc: 0.999995
# [186]	valid_0's auc: 0.999995
# [187]	valid_0's auc: 0.999996
# [188]	valid_0's auc: 0.999996
# [189]	valid_0's auc: 0.999996
# [190]	valid_0's auc: 0.999996
# [191]	valid_0's auc: 0.999996
# [279]	valid_0's auc: 0.999998
# [280]	valid_0's auc: 0.999998
# [281]	valid_0's auc: 0.999998
# [282]	valid_0's auc: 0.999998
# [283]	valid_0's auc: 0.999998
# [284]	valid_0's auc: 0.999997
# [285]	valid_0's auc: 0.999998
# [286]	valid_0's auc: 0.999998
# [287]	valid_0's auc: 0.999997
# [288]	valid_0's auc: 0.999997
# [289]	valid_0's auc: 0.999997
# [290]	valid_0's auc: 0.999997
# [291]	valid_0's auc: 0.999997
# [292]	valid_0's auc: 0.999997
# [293]	valid_0's auc: 0.999997
# [294]	valid_0's auc: 0.999997
# [295]	valid_0's auc: 0.999997
# [296]	valid_0's auc: 0.999997
# [297]	valid_0's auc: 0.999997
# [298]	valid_0's auc: 0.999997
# [299]	valid_0's auc: 0.999997
# [300]	valid_0's auc: 0.999997
# [301]	valid_0's auc: 0.999997
# [302]	valid_0's auc: 0.999997
# [303]	valid_0's auc: 0.999997
# [304]	valid_0's auc: 0.999997
# [305]	valid_0's auc: 0.999997
# [306]	valid_0's auc: 0.999997
# [307]	valid_0's auc: 0.999997
# [308]	valid_0's auc: 0.999997
# [309]	valid_0's auc: 0.999997
# [310]	valid_0's auc: 0.999997
# [311]	valid_0's auc: 0.999997
# [312]	valid_0's auc: 0.999998
# [313]	valid_0's auc: 0.999997
# [314]	valid_0's auc: 0.999998
# [315]	valid_0's auc: 0.999998
# [316]	valid_0's auc: 0.999998
# [317]	valid_0's auc: 0.999997
# [318]	valid_0's auc: 0.999997
# [319]	valid_0's auc: 0.999997
# [320]	valid_0's auc: 0.999997
# [321]	valid_0's auc: 0.999998
# [322]	valid_0's auc: 0.999998
# [323]	valid_0's auc: 0.999998
# [324]	valid_0's auc: 0.999998
# [325]	valid_0's auc: 0.999998
# [326]	valid_0's auc: 0.999998
# [327]	valid_0's auc: 0.999998
# [328]	valid_0's auc: 0.999998
# [329]	valid_0's auc: 0.999998
# [330]	valid_0's auc: 0.999998
# [331]	valid_0's auc: 0.999998
# [332]	valid_0's auc: 0.999998
# [333]	valid_0's auc: 0.999998
# [334]	valid_0's auc: 0.999998
# [335]	valid_0's auc: 0.999998
# [336]	valid_0's auc: 0.999998
# [337]	valid_0's auc: 0.999998
# [338]	valid_0's auc: 0.999998
# Early stopping, best iteration is:
# [238]	valid_0's auc: 0.999998

# %% [markdown]
# # Reading test data and  prediction over test data

# %%
test=pd.read_csv('Test.csv')

# %%
test.isnull().sum()
# Out:
# INCIDENT_ID      0
# DATE             0
# X_1              0
# X_2              0
# X_3              0
# X_4              0
# X_5              0
# X_6              0
# X_7              0
# X_8              0
# X_9              0
# X_10             0
# X_11             0
# X_12           127
# X_13             0
# X_14             0
# X_15             0
# dtype: int64

# %%
test=test.drop(columns=['INCIDENT_ID','DATE'])

test['X_12']=test['X_12'].fillna(test['X_12'].median())

# %%
ypredictions=model.predict(test)

# %%
for i in range(len(ypredictions)):
    if ypredictions[i]>0.5:
        ypredictions[i]=1
    else:
        ypredictions[i]=0

# %%
sub=pd.read_csv('test.csv')

sub['MULTIPLE_OFFENSE']=ypredictions

SUB=sub[['INCIDENT_ID','MULTIPLE_OFFENSE']]

SUB=SUB.set_index('INCIDENT_ID',drop=True)

sub_csv=SUB.to_csv('sol.csv')
